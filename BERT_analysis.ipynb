# %%
! pip3 install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.11.0+cpu)

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
print("Tokenizer loaded")
# Out:
# Tokenizer loaded

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Generative AI is powerful"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['genera', '##tive', 'ai', 'is', 'powerful']

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Generative AI is powerful"
inputs = tokenizer(text)
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"])
print(tokens)
# Out:
# ['[CLS]', 'genera', '##tive', 'ai', 'is', 'powerful', '[SEP]']

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model=AutoModelForSequenceClassification.from_pretrained("bert-base-uncased")
text = "AI is amazing"
inputs=tokenizer(text, return_tensors='pt')
# To get `last_hidden_state`, you need to set `output_hidden_states=True`.
outputs=model(**inputs, output_hidden_states=True)
print(outputs[:2])
print(outputs.hidden_states[-1].shape)
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[ 0.4130, -0.0617]], grad_fn=<AddmmBackward0>))
# torch.Size([1, 5, 768])

# %%
print("Outputs extracted successfully")
# Out:
# Outputs extracted successfully

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained("bert-base-uncased")
text="AI is amazing"
inputs=tokenizer(text)
print(inputs["attention_mask"])
# Out:
# [1, 1, 1, 1, 1]

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text1 = " What is AI?"
text2 = " AI means Artificial Intelligence"
inputs = tokenizer(text1, text2)
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"])
print(tokens)
# Out:
# ['[CLS]', 'what', 'is', 'ai', '?', '[SEP]', 'ai', 'means', 'artificial', 'intelligence', '[SEP]']

# %%
#Extract [CLS] Embedding
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

text = "AI is amazing"

inputs = tokenizer(text, return_tensors="pt")

outputs = model(**inputs)

cls_embedding = outputs.last_hidden_state[:,0,:]

print(f"CLS embedding extracted successfully with shape: {cls_embedding.shape}")
# Out:
# CLS embedding extracted successfully with shape: torch.Size([1, 768])
