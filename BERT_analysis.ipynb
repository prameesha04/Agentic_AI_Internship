# %% [markdown]
# <a href="https://colab.research.google.com/github/prameesha04/Agentic_AI_Internship/blob/main/BERT_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERT Model Analysis
#
# This notebook analyzes the BERT (Bidirectional Encoder Representations from Transformers) model architecture and provides insights into how the model works.

# %%
# Install required packages
# !pip install transformers torch

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Load BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

print(f"Model loaded: {model_name}")
print(f"Model type: {type(model)}")

# %%
# Display model configuration
print("Model Configuration:")
print(f"Hidden Size: {model.config.hidden_size}")
print(f"Number of Attention Heads: {model.config.num_attention_heads}")
print(f"Number of Hidden Layers: {model.config.num_hidden_layers}")
print(f"Intermediate Size: {model.config.intermediate_size}")
print(f"Vocab Size: {model.config.vocab_size}")
print(f"Max Position Embeddings: {model.config.max_position_embeddings}")

# %%
# Example text for analysis
text = "The BERT model is a powerful transformer-based language model."

# Tokenize the text
tokens = tokenizer.tokenize(text)
print(f"Original text: {text}")
print(f"Tokens: {tokens}")
print(f"Number of tokens: {len(tokens)}")

# %%
# Encode text and get embeddings
inputs = tokenizer(text, return_tensors="pt")
print("Input IDs shape:", inputs['input_ids'].shape)
print("Attention Mask shape:", inputs['attention_mask'].shape)

# Get model outputs
with torch.no_grad():
    outputs = model(**inputs)

# Extract embeddings
last_hidden_state = outputs.last_hidden_state
pooled_output = outputs.pooler_output

print(f"\nLast Hidden State shape: {last_hidden_state.shape}")
print(f"Pooled Output shape: {pooled_output.shape}")

# %% [markdown]
# ## Summary
#
# This notebook demonstrates:
# 1. Loading a pre-trained BERT model
# 2. Understanding model configuration
# 3. Tokenizing text
# 4. Generating embeddings
#
# BERT is a powerful model for various NLP tasks including text classification, named entity recognition, and question answering.
